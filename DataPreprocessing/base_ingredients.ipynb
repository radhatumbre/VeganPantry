# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
ingredients_list = []
with open('drinks_all_ingredients.txt', 'r') as file:
    # Create an empty list and a set for seen items
    seen = set()
    
    for line in file:
        item = line.strip()
        if item not in seen:
            ingredients_list.append(item)
            seen.add(item)

# Print the list
print(ingredients_list)
# Out:
# ['honey', 'fresh rosemary', 'cinnamon sticks', 'star anise', 'bourbon', 'lemon juice', 'apple butter or pumpkin butter', 'orange bitters', 'honey syrup', 'ginger beer, for topping', 'pomegranate juice', 'vodka', 'spiced apple butter', 'champagne', 'ginger beer', 'coarse sugar', 'brown sugar', 'candied ginger pieces, finely chopped', 'pomegranate juice, for the rim', 'apple cider vinegar', 'apple butter', 'sparkling white grape juice', 'granulated sugar', 'kosher salt', 'silver tequila', 'no sugar added cranberry juice', 'Cointreau', 'fresh lime juice', 'fresh or frozen cranberries', 'honey, use more or less to your taste', 'zest from 1 orange', 'ice', 'rosemary and sugared cranberries, for serving', 'juice from 1/2 a lime', 'orange zest', 'fresh cranberries', 'honey or maple syrup, using more or less to your taste', 'fresh ginger, sliced', 'all-spice berries', 'cloves', '100% cranberry or pomegranate juice', 'orange juice', 'sparkling water', 'chai spice sugar or cinnamon sugar, for 
# ...

# %%
base_ingredients = [
    "Lime",
    "pickled ginger",
    "pickled ginger juice",
    "pickled jalapeño",
    "pickle brine",
    "Pickle juice",
    "jalapeño",
    'jalapeńo',
    'jalapeno',
    "jalopeno",
    "ginger",
    "garlic",
    "peppers",
    
    
    
    "honey",
    "chili flake",
    "cucumber",
    "basil",
    "avocado",
    "peanut",
    "vinegar",
    "thyme",
    "arugula",
    
    "tacos",
    "lettuce",
    "Greek yogurt",
    
    
    
    "mayo",
    "buttermilk",
    "parsley",
    "dill",
    "garlic powder",
    "onion powder",
    "tortilla",
    "apple cider vinegar",
    'apple cider',
    "vinegar", "balsamic",
    "chive",
    "chile",
    "chili sauce",
    "chili powder",
    "chili paste",
    
    
    "cayenne pepper",
    'poblano pepper',
    'cayenne',
    "corn kernel",
    "corn",
    "peanut butter",
    "coconut milk",
    "rice noodle",
    "cashews",
    "red pepper flake",
    "egg",
    "butter",
    'buter'
    
    "cornmeal",
    "zucchini",
    "walnut",
    "bell pepper",
    "thyme",
    
    
    "tomato",
    "oregano",
    "cilantro",
    "paprika",
    "tomatillo",
    "lemon",
    "onion",
    "potato",
    "white wine",
    
    
    "asparagus",
    "artichoke",
    "pepperoni",'peperoncini',
    "pepperoncini",
    
    
#     cheese    
    "parmesan", "provolone", "havarti", "gouda", "provolone", "Mexican cheese", "cheddar", "blue cheese", "cheese",
    'pepper jack',
    'burrata',
    'mozzarella',
    'feta',
    'bocconcini',
    'brie',
    'fontina',
    'ricatta',
    'bocconcini',
    'goat chees',
    
#     bread    
    "bread", "ciabatta","baguette","Cuban buns" 
    "buns",
    "pita",
    'hoagie roll',
    'buns',
    
#     oil & sauce    
    "sesame oil",
    "olive oil",
    "oil",
    
    
    
#     sauce / syrup / curry
    "buffalo sauce",
    'BBQ sauce',
    "Sriracha",
    "fish sauce",
    "soy sauce",
    'Worcestershire',
    'worchestire',
    'tahini',
    'enchilada sauce',
    'ketchup',
    'oyster sauce',
    'hot sauce',
    'chipotle',
    'Russian Dressing',
    'marinara sauce',
    'ranch dressing',
    'barbecue sauce',
    'maple syrup',
    "mapley syrup",
    'tamari',
    'hoisin sauce',
    'Adobo Sauce',
    'tabasco',
    'Cranberry Sauce',
    "sun-dried tomato pesto",
    'pesto',
    'tartar',
    'molasses',
    'Thai red curry',
    
    
#     paste / dip / spread
    'dijon mustard',
    'mustard',
    'miso paste',
    'hummus',
    'salsa',
    'Gochujang',
    'Thai curry paste',
    'white miso',
    'ground mustard',
    'Guacamole',
    'Gochugaru',
    'kimichi',
     'Thai red curry paste',
    'sambal',
    'jam',
    'Tzakiki',
    'Tzatziki',
    'curry paste',
    'sour cream',
    'harissa',
    
    
#     frutis
    "mango",
    "pineapple",
    "tangerine",
    "apricot",
    "kiwi",
    "grapefruit",
    "strawberries",
    "strawberry",
    "blackberries",
    "blackberry",
    "grapes",
     "orange",
    "peach",
    'apple',
    'pomegranate juice',
    'pomegranate seed',
    'pomegranate',
    'cranberry juice'
    'raspberries',
    'raspberry',
    'cherries',
    'cherry',
    'blueberries',
    'blueberry',
    'cantaloupe',
    'berries',
    'pear',
    'nectarine',
    'watermelon',
    'cranberry juice',
    'cranberry',
    'fig',
    
    
#     pasta
    "pasta",
    "linguine",
    'spaghetti',
    'gnocchi',
    'rigatoni',
    'orzo',
    'macaroni',
    'cannelloni',
    'penne',
    'fettuccine',
    
#     dumplings
    'dumpling wrapper',
    'wonton wrapper',
    "perogies",
    'wonton',
    'dumpling',
    
#     alcohol
    "beer",
    'vodka',
    'brandy',
    'red wine',
    'marsala wine',
    'marsala',
    'sherry',
    'Cabernet',
    'bourbon',
    'tequila',

    
#     seeds
    "sesame seed",
    'pumpkin seed',
    'sunflower seed',
    'fennel seed',
    'caraway seed',
    'flax seed',
    'fennel',
    'chia seed',
    'toasted seed',
    
    
#     masala / herbs / seasoning

'bay leaf',
'nutmeg',
'cinnamon',
'cumin',
'turmeric',
'bay leaves',
'saffron',
'yeast',
'cardamom',
'cloves',
'baking powder',
'baking soda',
'bagel spice',
'bagel',
'red pepper',
    'bell pepers',
'sugar',
'mustard powder'
'red chilli',
    'red chillies',
'star anise',
'green chili',
'mint leaves',
'pickle',
'Italian seasoning',
'garam masala',
    'fresh herb',
    'cajun seasoning',
    'wasabi powder',
    'serrano pepper',
    'poultry seasoning',
    'Chinese 5 spice',
    "Chinese five spice",
    'Himalayan salt',
    'espresso powder',
    'vanilla extract',
    'mixed herbs',
    'chili pepper flakes',
    'mint',
    'pepper',
'seasoning',
    'vanilla',
           'pepper', 
    "kosher",
    'salt',
    
#     --------
    

    
    
    
    
# veggies
"bean sprout",
'pumpkin',
'brussels sprout',
'rosemary',
'sage',
'sweet potato',
'celery',
'sprouts','sprout',
'edamame',
'romaine',  # lettuce
'coriander',
'rhubarb',
'microgreen',
'micro green',    
 
#     flour / wrapping
    "all purpose flour",
"Taco",
'polenta',
'naan',
'all-purpose flour',
'all-purpose',
'puff pasty',
'puff pastry',
'pizza dough',   
'dinner rolls',
'croutons', 
'pastry sheet',
'semolina flour',
'Panko',
'buckwheat','flour',
'pie crust',
'sheet phyllo dough',
'phyllo dough',

#     beans
'chili bean',
'white bean',
'pinto bean',
'kidney bean',
    "cannelloni beans"
    
#     nuts
    'pine nut',
    'hazelnut',
    'pistachio',
    'almond',
    'pecan',
    'toasted nuts',
    
    
#     ----
    
    
    "black bean",
    "noodle",
    "scallion",
    "kimchi",
    "whiskey",    
    "coconut water",
    "coconut",
    "capers",
    "rice wine",
    "peas",
    
    
    "potato chip",
    "broccoli",
    "basmati rice",
    "rice",
    "anchovy",
    "stalk celery","stalks celery",
    "carrot",
    
    "curry powder",
    "leek",
    "quinoa",
    "vegetable broth",
    "beet green",
    "beets",
    "spaghetti squash",
    "bok choy",
    "spinach",
    
    "cabbage",
    "shallot",
    "carrot",
    "radish",
    "tofu",
    "mushroom",
    "kale",
    "squash",
    "olives",
    "cauliflower",
    
 #     sweet
'croissant',
'chocolate ice cream',
'chocolate malt powder',
'dark chocolate',
'chocolate',
'cocoa powder',
'whipped cream',
    
    
#     remaining
'plain yogurt',
'tater tot',
"pretzel",
'cracker',
'marshmallow fluff',
'milk',
'Heavy cream',
'Jelly',
'lentil',
'water',
'vegetables',
'greens',
'sesame',
'Nutella',
'cider',
'olive',
'green tea', 
    "heavvy cream",
    
    'cannellini',
    'cannelini',
    'nori',
    
#     done till here ---------------------------
    #sausage
    "pork sausage",  
    'andouille',
    'chorizo',
    
    #beef
    "steak",
    "ribs",
    'rib',
    'chuck roast',
    'brisket',
    'beef',
    
    
    #pork
    "bacon",  
    "pork chop",
    'pork',
    'pancetta',
    'ham',
    
    #poultry
    "chicken",
    'Turkey',
    
    #processed meat
    "salami",
    "prosciutto",
    'deli meat',
    
    #other meat
    'bison',
    "lamb",
    
    
    #fish
    "mahi mahi",
    'tuna',
    'salmon',
    "fish",
    
    #shellfish
    "shrimp",
    "scallops",
    'lobster',
    'mussel',
    'clams',
    
    
  'www.halfbakedharvest.com', 
    
    
    
    
    
    
  
    # dessert - new base ingredients

    
    'oats','oatmeal',
    
    
    'poppy seeds',
    'hemp seeds',
    
    


    
    
    
    
#     done
    'dried hibiscus',
    'dried rose petal',
    'rose petal',
    'star ansie',
    'Tajin', #seasoning
    
    
    #     alcohol
    'gin',
    'Campari',
    'elderflower liquor',
    'Cointreau',
    'Rosé wine',
    'sparkling rosé',
    'Rosé',
    'Rosè',
    'prosecco',
    'kahula',  'kahlua', 'Kahlúa', # kahlua
    'rum','scotch','Irish liquor',
    
    
    'candies','candy',
    'marshmallows',
    "M&M","M&M’s",'M + M s', 'M&Ms',"Hershey's Kisses",'Kisses','Snickers',"Snicker's",'Oreo',
    "Reese's","Reese’s",'Reese Cups',

    'grape juice',
    'plum',
    'persimmon',
    'banana','passion fruit',
    
    
    
    'brown suger'
    'ice',
    'dates',
    'pine nuts',
    'mixed nuts',
    'chestnuts',
    
    'dried rosmarry',
    
    'Heavy Whipping Cream','cream of tarter',
    'meringue','Irish Cream','cream',
    'cacao nibs',
'sprinkles',
    
    
    'coffee','espresso','tea','chai','expresso',
    'caramel',
    
    'doughnuts',
    "pastry dough",
    'waffles',
    
        'cardamon',
    'gelatin',
    'gelatin powder',
    
    #     sauce/ syrup
    'agave nectar',
    'hoisin',
    'thaini', # already suace exsists
    
    
    
]

# %%
# base_ingredients = ['sesame oil','pickled ginger juice', 'ginger','honey']

# %%
# remaning_ingr = []
# for i in range(1,7):
#     print(ingredients_list[i])
#     found = False
#     for j in base_ingredients:
#         if found == True:
#             break
#         if j in ingredients_list[i]:
#             found = True
#             continue
#     if found==False:
#         remaning_ingr.append(ingredients_list[i])

# %%
remaning_ingr = []
for i in ingredients_list:
    found = False
    for j in base_ingredients:
        if found == True:
            break
        if j.lower() in i.lower():
            found = True
            continue
    if found==False:
        remaning_ingr.append(i)

# %%
# remaning_ingr

# %%
len(ingredients_list)
# Out:
# 633

# %%
len(remaning_ingr)
# Out:
# 19

# %%
def save_list_to_txt(filename, data_list):
    with open(filename, 'w') as f:
        for item in data_list:
            f.write(f"{item}\n")

# %%
save_list_to_txt('drinks_rem_ingredients.txt', remaning_ingr)
