# %%
import pandas as pd
import numpy as np

# %% [markdown]
# ### mapping of ingredients to its base ingredient

# %%
import pickle

# Load the dictionary from the file
with open('mapping_dict.pkl', 'rb') as f:
    mapping_dict = pickle.load(f)

mapping_dict
# Out:
# {'lime': 'lime',
#  'pickled ginger': 'pickled ginger',
#  'pickled ginger juice': 'pickled ginger juice',
#  'pickled jalapeño': 'pickled jalapeño',
#  'pickle brine': 'pickle brine',
#  'pickle juice': 'pickle juice',
#  'jalapeño': 'jalapeño',
#  'jalapeńo': 'jalapeño',
#  'jalapeno': 'jalapeño',
#  'jalopeno': 'jalapeño',
#  'ginger': 'ginger',
#  'garlic': 'garlic',
#  'peppers': 'bell pepper',
#  'bell pepper': 'bell pepper',
#  'honey': 'honey',
#  'chili flake': 'chili flake',
#  'cucumber': 'cucumber',
#  'basil': 'basil',
#  'avocado': 'avocado',
#  'avocdos': 'avocado',
#  'peanut': 'peanut',
#  'vinegar': 'vinegar',
#  'thyme': 'thyme',
#  'arugula': 'arugula',
#  'tacos': 'taco shells',
#  'lettuce': 'lettuce',
#  'Greek yogurt': 'yogurt',
#  'mayo': 'mayo',
#  'buttermilk': 'buttermilk',
#  'parsley': 'parsley',
#  'dill': 'dill',
#  'garlic powder': 'garlic powder',
#  'onion powder': 'onion powder',
#  'tortilla': 'tortilla',
#  'apple cider vinegar': 'apple cider vinegar',
#  'apple cider': 'apple cider vinegar',
#  'balsamic': 'vinegar',
#  'chive': 'chive',
#  'chile': 'chile',
#  'chili sauce': 'chili sauce',
#  'chili powder': 'chili powder',
#  'chili paste': 'chili paste',
#  'cayenne pepper': 'pepper',
#  'poblano pepper': 'pepper',
#  'cayenne': 'pepper',
#  'corn kernel': 'corn kernel',
#  'corn': 'corn',
#  'peanut butter': 'peanut butter',
#  'coconut milk': 'coconut milk',
#  'rice noodle': 'rice noodle',
#  'cashews': 'cashews',
#  'red pepper flake': 'red pepper flake',
#  'egg': 'egg',
#  'butter': 'butter',
#  'buter': 'butter',
#  'cornmeal': 'cornmeal',
#  'zucchini': 'zucchini',
#  'walnut': 'walnut',
#  'tomato': 'tomato',
#  'oregano': 'oregano',
#  'cilantro': 'cilantro',
#  'paprika': 'paprika',
#  'tomatillo': 'tomatillo',
#  'lemon': 'lemon',
#  'onion': 'onion',
#  'potato': 'potato',
#  'white wine': 'white wine',
#  'asparagus': 'asparagus',
#  'artichoke': 'artichoke',
#  'pepperoni': 'peperoncino',
#  'peperoncini': 'peperoncino',
#  'pepperoncini': 'peperoncino',
#  'parmesan': 'cheese',
#  'provolone': 'cheese',
#  'havarti': 'cheese',
#  'gouda': 'cheese',
#  'Mexican cheese': 'cheese',
#  'cheddar': 'cheese',
#  'pepper jack': 'cheese',
#  'blue cheese': 'cheese',
#  'cheese': 'cheese',
#  'burrata': 'cheese',
#  'mozzarella': 'cheese',
#  'feta': 'cheese',
#  'bocconcini': 'cheese',
#  'brie': 'cheese',
#  'fontina': 'cheese',
#  'ricatta': 'cheese',
#  'goat chees': 'cheese',
#  'bread': 'bread',
#  'ciabatta': 'bread',
#  'baguette': 'bread',
#  'cuban buns': 'bread',
#  'pita': 'bread',
#  'buns': 'buns',
#  'hoagie roll': 'bread',
#  'sesame oil': 'sesame oil',
#  'olive oil': 'olive oil',
#  'oil': 'oil',
#  'Worcestershire': 'worcestershire sauce',
#  'worchestire': 'worcestershire sauce',
#  'Thai red curry': 'thai red curry',
#  'tamari': 'tamari',
#  'tabasco': 'tabasco',
#  'tartar': 'tartar',
#  'Sriracha': 'Sriracha',
#  'soy sauce': 'soy sauce',
#  'Russian Dressing': 'Russian Dressing',
#  'ranch dressing': 'ranch dressing',
#  'sun-dried tomato pesto': 'tomato pesto',
#  'pesto': 'pesto',
#  'oyster sauce': 'oyster sauce',
#  'molasses': 'molasses',
#  'maple syrup': 'maple syrup',
#  'mapley syrup': 'maple syrup',
#  'marinara sauce': 'marinara sauce',
#  'hoisin sauce': 'hoisin sauce',
#  'hot sauce': 'hot sauce',
#  'fish sauce': 'fish sauce',
#  'enchilada sauce': 'enchilada sauce',
#  'chipotle': 'chipotle',
#  'cranberry sauce': 'cranberry dauce',
#  'buffalo sauce': 'buffalo sauce',
#  'BBQ sauce': 'BBQ sauce',
#  'barbecue sauce': 'BBQ sauce',
#  'Adobo Sauce': 'Adobo Sauce',
#  'ketchup': 'ketchup',
#  'tahini': 'tahini',
#  'white miso': 'white miso',
#  'Tzatziki': 'tzatziki',
#  'Tzakiki': 'tzatziki',
#  'Thai red curry paste': 'thai red curry paste',
#  'Thai curry paste': 'thai curry paste',
#  'sour cream': 'sour cream',
#  'sambal': 'sambal',
#  'salsa': 'salsa',
#  'miso paste': 'miso paste',
#  'kimichi': 'kimichi',
#  'jam': 'jam',
#  'hummus': 'hummus',
#  'harissa': 'harissa',
#  'Guacamole': 'guacamole',
#  'Gochujang': 'gochujang',
#  'Gochugaru': 'gochugaru',
#  'ground mustard': 'ground mustard',
#  'dijon mustard': 'dijon mustard',
#  'mustard': 'mustard',
#  'curry paste': 'curry paste',
#  'watermelon': 'watermelon',
#  'tangerine': 'tangerine',
#  'strawberry': 'strawberry',
#  'strawberries': 'strawberry',
#  'raspberry': 'raspberry',
#  'raspberries': 'raspberry',
#  'pomegranate seed': 'pomegranate seed',
#  'pomegranate juice': 'pomegranate juice',
#  'pomegranate': 'pomegranate',
#  'pineapple': 'pineapple',
#  'pear': 'pear',
#  'peach': 'peach',
#  'orange': 'orange',
#  'nectarine': 'nectarine',
#  'mango': 'mango',
#  'kiwi': 'kiwi',
#  'grapes': 'grapes',
#  'grapefruit': 'grapefruit',
#  'cranberry juice': 'cranberry juice',
#  'cranberry': 'cranberry',
#  'cantaloupe': 'cantaloupe',
#  'cherry': 'cherry',
#  'cherries': 'cherry',
#  'blueberry': 'blueberry',
#  'blueberries': 'blueberry',
#  'blackberry': 'blackberry',
#  'blackberries': 'blackberry',
#  'berries': 'berries',
#  'apricot': 'apricot',
#  'apple': 'apple',
#  'fig': 'fig',
#  'pasta': 'pasta',
#  'linguine': 'pasta',
#  'spaghetti': 'pasta',
#  'gnocchi': 'pasta',
#  'rigatoni': 'pasta',
#  'orzo': 'pasta',
#  'macaroni': 'pasta',
#  'cannelloni': 'pasta',
#  'penne': 'pasta',
#  'fettuccine': 'pasta',
#  'black bean': 'black bean',
#  'noodle': 'noodle',
#  'scallion': 'scallion',
#  'kimchi': 'kimchi',
#  'whiskey': 'whiskey',
#  'coconut water': 'coconut water',
#  'coconut': 'coconut',
#  'capers': 'capers',
#  'rice wine': 'rice wine',
#  'peas': 'peas',
#  'potato chip': 'potato chip',
#  'broccoli': 'broccoli',
#  'basmati rice': 'rice',
#  'rice': 'rice',
#  'anchovy': 'anchovy',
#  'stalks celery': 'stalk celery',
#  'stalk celery': 'stalk celery',
#  'carrot': 'carrot',
#  'curry powder': 'curry powder',
#  'leek': 'leek',
#  'quinoa': 'quinoa',
#  'vegetable broth': 'vegetable broth',
#  'beet green': 'beet green',
#  'beets': 'beets',
#  'spaghetti squash': 'spaghetti squash',
#  'bok choy': 'bok choy',
#  'spinach': 'spinach',
#  'cabbage': 'cabbage',
#  'shallot': 'shallot',
#  'radish': 'radish',
#  'tofu': 'tofu',
#  'mushroom': 'mushroom',
#  'kale': 'kale',
#  'squash': 'squash',
#  'olives': 'olive',
#  'cauliflower': 'cauliflower',
#  'dumpling wrapper': 'wonton wrapper',
#  'wonton wrapper': 'wonton wrapper',
#  'perogies': 'dumpling',
#  'wonton': 'dumpling',
#  'dumpling': 'dumpling',
#  'vodka': 'vodka',
#  'tequila': 'tequila',
#  'sherry': 'sherry',
#  'red wine': 'red wine',
#  'marsala wine': 'marsala wine',
#  'marsala': 'marsala wine',
#  'brandy': 'brandy',
#  'bourbon': 'bourbon',
#  'beer': 'beer',
#  'cabernet': 'cabernet',
#  'toasted seed': 'toasted seed',
#  'sunflower seed': 'sunflower seed',
#  'sesame seed': 'sesame seed',
#  'pumpkin seed': 'pumpkin seed',
#  'flax seed': 'flax seed',
#  'fennel seed': 'fennel seed',
#  'fennel': 'fennel',
#  'chia seed': 'chia seed',
#  'caraway seed': 'caraway seed',
#  'vanilla extract': 'vanilla extract',
#  'vanilla': 'vanilla',
#  'turmeric': 'turmeric',
#  'star anise': 'star anise',
#  'sugar': 'sugar',
#  'serrano pepper': 'serrano pepper',
#  'saffron': 'saffron',
#  'red pepper': 'bell pepper',
#  'bell pepers': 'bell pepper',
#  'red chilli': 'red chilli',
#  'red chillies': 'red chilli',
#  'poultry seasoning': 'poultry seasoning',
#  'nutmeg': 'nutmeg',
#  'mustard powder': 'mustard powder',
#  'mixed herbs': 'herbs',
#  'mint leaves': 'mint leaves',
#  'mint': 'mint leaves',
#  'kosher': 'salt',
#  'Himalayan salt': 'salt',
#  'salt': 'salt',
#  'Italian seasoning': 'Italian seasoning',
#  'garam masala': 'garam masala',
#  'green chili': 'green chili',
#  'fresh herb': 'herbs',
#  'espresso powder': 'coffee powder',
#  'cumin': 'cumin',
#  'cinnamon': 'cinnamon',
#  'cardamom': 'cardamom',
#  'chili pepper flakes': 'chili flakes',
#  'Chinese 5 spice': 'Chinese 5 spice',
#  'Chinese five spice': 'Chinese 5 spice',
#  'bay leaves': 'bay leaf',
#  'bay leaf': 'bay leaf',
#  'bagel spice': 'bagel spice',
#  'bagel': 'bagel',
#  'baking powder': 'baking powder',
#  'baking soda': 'baking soda',
#  'cloves': 'cloves',
#  'cajun seasoning': 'cajun seasoning',
#  'wasabi powder': 'wasabi powder',
#  'yeast': 'yeast',
#  'pepper': 'pepper',
#  'seasoning': 'seasoning',
#  'pickle': 'pickle',
#  'sweet potato': 'sweet potato',
#  'rosemary': 'rosemary',
#  'rhubarb': 'rhubarb',
#  'romaine': 'lettuce',
#  'sage': 'sage',
#  'brussels sprout': 'brussels sprout',
#  'bean sprout': 'bean sprout',
#  'sprouts': 'sprout',
#  'sprout': 'sprout',
#  'pumpkin': 'pumpkin',
#  'microgreen': 'microgreen',
#  'micro green': 'microgreen',
#  'edamame': 'edamame',
#  'coriander': 'coriander',
#  'celery': 'celery',
#  'semolina flour': 'semolina flour',
#  'semolina': 'semolina flour',
#  'sheet phyllo dough': 'phyllo dough',
#  'puff pastry': 'puff pastry',
#  'puff pasty': 'puff pastry',
#  'pizza dough': 'pizza dough',
#  'phyllo dough': 'phyllo dough',
#  'polenta': 'polenta',
#  'Panko': 'panko',
#  'pie crust': 'pie crust',
#  'pastry sheet': 'pastry sheet',
#  'naan': 'naan',
#  'buckwheat': 'buckwheat',
#  'croutons': 'crouton',
#  'dinner rolls': 'dinner rolls',
#  'taco': 'taco shells',
#  'all purpose flour': 'all purpose flour',
#  'all-purpose': 'all purpose flour',
#  'all-purpose flour': 'all purpose flour',
#  'flour': 'flour',
#  'white bean': 'white bean',
#  'pinto bean': 'pinto bean',
#  'kidney bean': 'kidney bean',
#  'chili bean': 'chili bean',
#  'cannelloni beans': 'cannelloni bean',
#  'toasted nuts': 'toasted nuts',
#  'pistachio': 'pistachio',
#  'pecan': 'pecan',
#  'pine nut': 'pine nut',
#  'hazelnut': 'hazelnut',
#  'almond': 'almond',
#  'whipped cream': 'whipped cream',
#  'dark chocolate': 'dark chocolate',
#  'cocoa powder': 'cocoa powder',
#  'chocolate malt powder': 'chocolate malt powder',
#  'chocolate ice cream': 'chocolate ice cream',
#  'chocolate': 'chocolate',
#  'croissant': 'croissant',
#  'water': 'water',
#  'vegetables': 'vegetable',
#  'tater tot': 'tater tot',
#  'sesame': 'sesame',
#  'pretzel': 'pretzel',
#  'plain yogurt': 'yogurt',
#  'olive': 'olive',
#  'Nutella': 'nutella',
#  'milk': 'milk',
#  'marshmallow fluff': 'marshmallow',
#  'lentil': 'lentil',
#  'Jelly': 'jelly',
#  'Heavy cream': 'Heavy cream',
#  'heavvy cream': 'Heavy cream',
#  'green tea': 'green tea',
#  'greens': 'greens',
#  'cracker': 'cracker',
#  'cider': 'cider',
#  'pork sausage': 'meat - sausage - pork sausage',
#  'andouille': 'meat - sausage - andouille',
#  'chorizo': 'meat - sausage - chorizo',
#  'steak': 'meat - beef - steak',
#  'ribs': 'meat - beef - ribs',
#  'rib': 'meat - beef - ribs',
#  'chuck roast': 'meat - beef - chuck roast',
#  'brisket': 'meat - beef - brisket',
#  'beef': 'meat - beef - beef',
#  'bacon': 'meat - pork - bacon',
#  'pork chop': 'meat - pork - pork chop',
#  'pork': 'meat - pork - pork',
#  'pancetta': 'meat - pork - pancetta',
#  'ham': 'meat - pork - ham',
#  'chicken': 'meat - poultry - chicken',
#  'Turkey': 'meat - poultry - turkey',
#  'salami': 'meat - processed meat - salami',
#  'prosciutto': 'meat - processed meat - prosciutto',
#  'deli meat': 'meat - processed meat - deli meat',
#  'bison': 'meat - other meat - bison',
#  'lamb': 'meat - other meat - lamb',
#  'mahi mahi': 'meat - fish - mahi mahi',
#  'tuna': 'meat - fish - tuna',
#  'salmon': 'meat - fish - salmon',
#  'fish': 'meat - fish',
#  'shrimp': 'meat - fish - shellfish - shrimp',
#  'scallops': 'meat - fish - shellfish - scallops',
#  'lobster': 'meat - fish - shellfish - lobster',
#  'mussel': 'meat - fish - shellfish - mussel',
#  'clams': 'meat - fish - shellfish - clams',
#  'cannellini': 'cannellini',
#  'cannelini': 'cannellini',
#  'nori': 'nori'}

# %% [markdown]
# ### list of non-vegan ingredients in the database

# %%
with open('non_vegan_ingredients.txt', 'r') as file:
    non_vegan_ingr = [line.strip() for line in file]

non_vegan_ingr
# Out:
# ['anchovy',
#  'bbq sauce',
#  'beer',
#  'buffalo sauce',
#  'butter',
#  'buttermilk',
#  'cheese',
#  'chocolate',
#  'chocolate ice cream',
#  'chocolate malt powder',
#  'egg',
#  'fish sauce',
#  'heavy cream',
#  'honey',
#  'marsala wine',
#  'marshmallow',
#  'mayo',
#  'meat - beef - beef',
#  'meat - beef - brisket',
#  'meat - beef - chuck roast',
#  'meat - beef - ribs',
#  'meat - beef - steak',
#  'meat - fish',
#  'meat - fish - mahi mahi',
#  'meat - fish - salmon',
#  'meat - fish - shellfish - clams',
#  'meat - fish - shellfish - lobster',
#  'meat - fish - shellfish - mussel',
#  'meat - fish - shellfish - scallops',
#  'meat - fish - shellfish - shrimp',
#  'meat - fish - tuna',
#  'meat - other meat - bison',
#  'meat - other meat - lamb',
#  'meat - pork - bacon',
#  'meat - pork - ham',
#  'meat - pork - pancetta',
#  'meat - pork - pork',
#  'meat - pork - pork chop',
#  'meat - poultry - chicken',
#  'meat - poultry - turkey',
#  'meat - processed meat - deli meat',
#  'meat - processed meat - prosciutto',
#  'meat - processed meat - salami',
#  'meat - sausage - andouille',
#  'meat - sausage - chorizo',
#  'meat - sausage - pork sausage',
#  'milk',
#  'nutella',
#  'oyster sauce',
#  'panko',
#  'pickle brine',
#  'pickle juice',
#  'pickled ginger',
#  'pickled ginger juice',
#  'pickled jalapeño',
#  'poultry seasoning',
#  'rice wine',
#  'sherry',
#  'tequila']

# %% [markdown]
# ### alternatives to non-vegan ingredients

# %%
df_non_vegan_alter = pd.read_csv('nonvegan-alternatives.csv')
df_non_vegan_alter
# Out:
#                         BaseIngredient  \
# 0                              anchovy
# 1                            bbq sauce
# 2                                 beer
# 3                        buffalo sauce
# 4                               butter
# 5                           buttermilk
# 6                               cheese
# 7                            chocolate
# 8                  chocolate ice cream
# 9                chocolate malt powder
# 10                                 egg
# 11                          fish sauce
# 12                         heavy cream
# 13                               honey
# 14                        marsala wine
# 15                         marshmallow
# 16                                mayo
# 17                  meat - beef - beef
# 18               meat - beef - brisket
# 19           meat - beef - chuck roast
# 20                  meat - beef - ribs
# 21                 meat - beef - steak
# 22                         meat - fish
# 23             meat - fish - mahi mahi
# 24                meat - fish - salmon
# 25     meat - fish - shellfish - clams
# 26   meat - fish - shellfish - lobster
# 27    meat - fish - shellfish - mussel
# 28  meat - fish - shellfish - scallops
# 29    meat - fish - shellfish - shrimp
# 30                  meat - fish - tuna
# 31           meat - other meat - bison
# 32            meat - other meat - lamb
# 33                 meat - pork - bacon
# 34                   meat - pork - ham
# 35              meat - pork - pancetta
# 36                  meat - pork - pork
# 37             meat - pork - pork chop
# 38            meat - poultry - chicken
# 39             meat - poultry - turkey
# 40   meat - processed meat - deli meat
# 41  meat - processed meat - prosciutto
# 42      meat - processed meat - salami
# 43          meat - sausage - andouille
# 44            meat - sausage - chorizo
# 45       meat - sausage - pork sausage
# 46                                milk
# 47                             nutella
# 48                        oyster sauce
# 49                               panko
# 50                        pickle brine
# 51                        pickle juice
# 52                      pickled ginger
# 53                pickled ginger juice
# 54                    pickled jalapeño
# 55                   poultry seasoning
# 56                           rice wine
# 57                              sherry
# 58                             tequila
#
#                                     VeganAlternative
# 0                                         miso paste
# 1                                       Hoisin sauce
# 2                                    sparkling water
# 3                                          hot sauce
# 4                                        coconut oil
# 5                    non-dairy milk with lemon juice
# 6                        Cashew Cheese, vegan cheese
# 7                                       cocoa powder
# 8                      Non-dairy chocolate ice cream
# 9                                       cocoa powder
# 10                                       Silken tofu
# 11                                         Soy sauce
# 12                                      Cashew cream
# 13                                       Maple syrup
# 14  white wine, red wine, non-alcoholic marsala wine
# 15                                Vegan marshmallows
# 16                                        Vegan mayo
# 17                                Seitan, Vegan beef
# 18                           Jackfruit,vegan brisket
# 19                    Cauliflower, Vegan Chuck Roast
# 20                              Jackfruit,vegan ribs
# 21                             Mushrooms,vegan steak
# 22                              Jackfruit,vegan fish
# 23                   hearts of palm, vegan mahi mahi
# 24                     Carrot,beetroot, vegan salmon
# 25                             artichoke,vegan clams
# 26                     hearts of palm, vegan lobster
# 27                            mushrooms,vegan mussel
# 28                          mushrooms,vegan scallops
# 29                            mushrooms,vegan shrimp
# 30                               Chickpea,vegan tuna
# 31                                seitan,vegan bison
# 32                        Mushroom,seitan,vegan lamb
# 33                        tempeh,coconut,vegan bacon
# 34                             tofu,seitan,vegan ham
# 35      Coconut bacon, tofu or tempeh,Vegan pancetta
# 36              Mushroom,seitan,Jackfruit,Vegan pork
# 37                       tofu,tempeh,Vegan pork chop
# 38             Chickpea,tofu,Jackfruit,Vegan chicken
# 39                               Seitan,Vegan turkey
# 40                       tofu,tempeh,Vegan deli meat
# 41                 eggplant,coconut,Vegan prosciutto
# 42                  mushroom,beet slice,vegan salami
# 43                          mushroom,vegan andouille
# 44                        tofu, tempeh,Vegan chorizo
# 45                Tofu,tempeh,Mushroom,vegan sausage
# 46                   almond milk, soy milk, oat milk
# 47                            Vegan chocolate spread
# 48                                         soy sauce
# 49                                        cornflakes
# 50                               Apple cider vinegar
# 51                                       Lemon juice
# 52                                      ginger syrup
# 53                                      ginger syrup
# 54                             jalapeño with vinegar
# 55                                             herbs
# 56                                      Rice vinegar
# 57                                        white wine
# 58                                        Lime juice

# %% [markdown]
# ## Function mapping ingredients to base ingredient

# %%
def extract_base_ingr(ingredients_list, instructions):
    base_ingr = []
    for ingr in ingredients_list:
        ingr = ingr.lower()
        found = False
        for key in mapping_dict:
            if found == True:
                break
            if key.lower() in ingr:
                found = True
                base_ingr.append(mapping_dict[key].lower())
              
    # remove duplicates
    seen = set()
    base_ingr = [x for x in base_ingr if not (x in seen or seen.add(x))]
    return base_ingr

# %% [markdown]
# ## Function mapping ingredients to base ingredient in INSTRUCTIONS

# %%
def base_instructions(instructions,ingredients_list):
    for ingr in ingredients_list:
        ingr = ingr.lower()
        found = False
        for key in mapping_dict:
            if found == True:
                break
            if key.lower() in ingr:
                found = True
                instructions = instructions.replace(key.lower(),mapping_dict[key].lower())
    return instructions

# %% [markdown]
# ## Function - Mapping Non-Vegan ingredient to Vegan Ing.

# %%
def conver_to_vegan(ingr_list):
    vegan_list = []
    for i in ingr_list:
        if i in non_vegan_ingr:
            filtered_df = df_non_vegan_alter[df_non_vegan_alter['BaseIngredient'] == i]
            # Get the comma-separated strings from column 'VeganAlternative'
            vegan_alternatives = filtered_df['VeganAlternative']
            # Split the strings by comma and flatten the list
            result_list = [item.strip() for sublist in vegan_alternatives.str.split(',') for item in sublist]
            for alter in result_list:
                vegan_list.append(alter)
        else:
            vegan_list.append(i)
            
    return vegan_list

# %% [markdown]
# ## Function - Mapping Non-Vegan ingredient to Available Vegan Ing. in INSTRUCTIONS

# %%
def instructions_with_vegan_available(instructions, ingr_list):
    for i in ingr_list:
        if i in non_vegan_ingr:
            filtered_df = df_non_vegan_alter[df_non_vegan_alter['BaseIngredient'] == i]
            vegan_alternatives = filtered_df['VeganAlternative']
            result_list = [item.strip() for sublist in vegan_alternatives.str.split(',') for item in sublist]
            found = False
            for alter in result_list:
                if alter in user_ingrs:
                    instructions = instructions.replace(i, alter)
                    found = True
                    break
            if not found:
                instructions = instructions.replace(i, result_list[0])
    # return instructions

# %% [markdown]
# ## Function - Recipes with atleast 3 ingredients available

# %%
def check_ingredients(recipe_ingredients, user_ingredients):
    recipe_ingredients_set = set(recipe_ingredients)
    common_ingredients = recipe_ingredients_set.intersection(user_ingredients)
    return len(common_ingredients) >= 3

# %% [markdown]
# ## Function - Creating Tags for vectiorization

# %%
def tags_vegan_available(ingr_list,user_ingrs):
    vegan_list = []
    for i in ingr_list:
        if i in non_vegan_ingr:
            filtered_df = df_non_vegan_alter[df_non_vegan_alter['BaseIngredient'] == i]
            vegan_alternatives = filtered_df['VeganAlternative']
            result_list = [item.strip() for sublist in vegan_alternatives.str.split(',') for item in sublist]
            
            found = False
            for alter in result_list:
                if alter in user_ingrs:
                    vegan_list.append(alter)
                    found = True
                    break
            if not found:
                vegan_list.append(result_list[0])
        else:
            vegan_list.append(i)
    result_string = ', '.join(vegan_list)
    return str(result_string)

# %%
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.metrics.pairwise import cosine_similarity

# %%
def recommend_recipes(user_ingrs):
    # Step 1: Convert ingredients to base ingredients
    df['base_ingredients'] = df.apply(lambda row: extract_base_ingr(row['ingredients'], row['instructions']), axis=1)
    
    # Step 2: Replace instructions with base ingredients
    df['instructions'] = df.apply(lambda row: base_instructions(row['instructions'], row['ingredients']), axis=1)
    
    # Step 3: Convert ingredients to vegan ingredients
    df['vegan_ingredients'] = df['base_ingredients'].apply(conver_to_vegan)
    
    # Step 4: Filter recipes with at least 3 matching ingredients
    df['HasEnoughIngredients'] = df['vegan_ingredients'].apply(lambda x: check_ingredients(x, user_ingrs))
    suitable_recipes = df[df['HasEnoughIngredients']]
    
    # Step 5: Adjust vegan ingredients with available user ingredients
    suitable_recipes['tags'] = suitable_recipes['base_ingredients'].apply(lambda x: tags_vegan_available(x, user_ingrs))
    
    # Step 6: Replace instructions with vegan alternatives available to the user
    suitable_recipes['instructions'] = suitable_recipes.apply(lambda row: instructions_with_vegan_available(row['instructions'], row['base_ingredients']), axis=1)
    
    # Step 7: Create ingredient matrix for similarity calculation
    vectorizer = CountVectorizer(tokenizer=lambda x: x.split(', '))
    X = vectorizer.fit_transform(suitable_recipes['tags'])
    
    # Step 8: Calculate cosine similarity between user ingredients and recipes
    user_vector = vectorizer.transform([', '.join(user_ingrs)])
    similarities = cosine_similarity(user_vector, X).flatten()
    
    # Step 9: Add similarity scores and sort recipes by similarity
    suitable_recipes['Similarity'] = similarities
    recommended_recipes = suitable_recipes.sort_values(by='Similarity', ascending=False)
    
    # Step 10: Return recommended recipes
    return recommended_recipes[['title', 'Similarity', 'instructions']]

# %%
# user_ingrs = ['lime', 'sesame oil','garlic', 'fish sauce', 'ginger','bell pepper','tofu','cashew cheese','honey','butter','chili paste']

# %%
df = pd.read_csv('recipes_final.csv')

# %%
# Example usage:
user_ingrs = ['lime', 'sesame oil','garlic', 'fish sauce', 'ginger','bell pepper','tofu','cashew cheese','honey','butter','chili paste']
recommended = recommend_recipes(user_ingrs)
print("Recommended Recipes:")
print(recommended)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /var/folders/vx/738z10qd2gb7rhy7_rz19c3w0000gn/T/ipykernel_12827/1327432190.py in ?()
# ----> 3 # Example usage:
#       4 user_ingrs = ['lime', 'sesame oil','garlic', 'fish sauce', 'ginger','bell pepper','tofu','cashew cheese','honey','butter','chili paste']
#       5 recommended = recommend_recipes(user_ingrs)
#       6 print("Recommended Recipes:")
#
# /var/folders/vx/738z10qd2gb7rhy7_rz19c3w0000gn/T/ipykernel_12827/3937723097.py in ?(user_ingrs)
#      15     # Step 5: Adjust vegan ingredients with available user ingredients
#      16     suitable_recipes['tags'] = suitable_recipes['base_ingredients'].apply(lambda x: tags_vegan_available(x, user_ingrs))
#      17
#      18     # Step 6: Replace instructions with vegan alternatives available to the user
# ---> 19     suitable_recipes['instructions'] = suitable_recipes.apply(lambda row: instructions_with_vegan_available(row['instructions'], row['base_ingredients']), axis=1)
#      20
#      21     # Step 7: Create ingredient matrix for similarity calculation
#      22     vectorizer = CountVectorizer(tokenizer=lambda x: x.split(', '))
#
# /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/pandas/core/frame.py in ?(self, key, value)
#    3964             self._setitem_frame(key, value)
#    3965         elif isinstance(key, (Series, np.ndarray, list, Index)):
#    3966             self._setitem_array(key, value)
#    3967         elif isinstance(value, DataFrame):
# -> 3968             self._set_item_frame_value(key, value)
#    3969         elif (
#    3970             is_list_like(value)
#    3971             and not self.columns.is_unique
#
# /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/pandas/core/frame.py in ?(self, key, value)
#    4094             loc = self.columns.get_loc(key)
#    4095             cols = self.columns[loc]
#    4096             len_cols = 1 if is_scalar(cols) else len(cols)
#    4097             if len_cols != len(value.columns):
# -> 4098                 raise ValueError("Columns must be same length as key")
#    4099
#    4100             # align right-hand-side columns if self.columns
#    4101             # is multi-index and self[key] is a sub-frame
#
# ValueError: Columns must be same length as key

# %%
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[17], line 3
#       1 # Example usage:
#       2 user_ingrs = ['lime', 'sesame oil','garlic', 'fish sauce', 'ginger','bell pepper','tofu','cashew cheese','honey','butter','chili paste']
# ----> 3 recommended = recommend_recipes(user_ingrs)
#       4 print("Recommended Recipes:")
#       5 print(recommended)
#
# TypeError: recommend_recipes() missing 1 required positional argument: 'user_ingrs'
